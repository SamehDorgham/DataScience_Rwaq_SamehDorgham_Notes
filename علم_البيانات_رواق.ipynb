# %% [markdown]
# <a href="https://colab.research.google.com/github/SamehDorgham/DataScience_Rwaq_SamehDorgham_Notes/blob/main/%D8%B9%D9%84%D9%85_%D8%A7%D9%84%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA_%D8%B1%D9%88%D8%A7%D9%82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **File Name : { DataScience_Rwaq_SamehDorgham_Notes }**

# %% [markdown]
# ![علوم البيانات من الصفر للاحتراف - رواق.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **علم البيانات - رواق**
#
# https://www.rwaq.org/courses/data-scientist-from0

# %% [markdown]
# *********************************************************
#
#
# ![مساق علم البيانات - GitHub.jpg](data:image/jpeg;base64,...)
#
#
# **علم البيانات - رواق**
#
# https://www.rwaq.org/courses/data-scientist-from0
#
# ...
# ...
#
#
# **واتس الباشمهندس / مصطفي نبيه**
#
# **PHONE : +201015197566**
#
# ...
# ...
# ...
#
# *********************************************************

# %% [markdown]
# ***************************************************************************
#
# **مواعيد نزول المحاضرات**
# -------------------------------------------
#
# ان شاء الله المحاضرات تقسم على ثلاثة ايام فى الاسبوع:
# الاحد والثلاثاء والخميس تنزل المحاضرات الساعة 12 ظهرا بتوقيت السعودية من كل اسبوع
#
# ان شاء الله يوم الجمعة ينزل اسئلة لحلها و مع محاضرة تكون مباشر مع جميع الطلاب يتم ارسال رابط المحاضرة قبلها
#
#
# ...
# ...
# ...

# %% [markdown]
# ![VIP URLs.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **روابط هامة**
#
# 1- برنامج أناكوندا Anaconda لتشغيل أوامر بايثون علي جهازك
#
# https://www.anaconda.com/products/individual-d
#
# ...
#
# 2- جوجل كولاب Google Colab لتشغيل أوامر بايثون علي النت
#
# https://colab.research.google.com/notebooks
#
# ...
#
# 3- موقع هكر رانك Hacker Rank لحل مسائل وتمارين علي بايثون
#
# https://www.hackerrank.com/
#
# ...
#
# 4- رابط الماتريال الخاص بالكورس على موقع جيت هب Github
#
# https://github.com/DataScienceClub2021/Data-science-from-zero-to-hero
#
# ...
#
#
# 5-A- قناة التليجرام Telegram Channel :
#
# https://t.me/Data_ScienceClub
#
#
# 5-B- قناة تليجرام الطلبةTelegram Channel :
#
# https://t.me/DATAscienceandCcoladandPYTHON658
#
# ...

# %% [markdown]
# ![Problem Solving.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![حل الواجب - علم البيانات - رواق.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **{ واجب الأسبوع الأول }**
#
# **الواجب نزل يا جماعة النهاردة 20-9-2021  ... وآخر يوم للتسليم يوم 1-12-2021**
#
# ...
#
# 1- المسألة رقم 1 :  Hello World
#
# https://www.hackerrank.com/challenges/py-hello-world/problem
#
# ...
#
# 2- المسألة رقم 2 : Arithmetic Operators
#
# https://www.hackerrank.com/challenges/python-arithmetic-operators/problem
#
# ...
# ...
#
# أولاً : يتم عمل حساب علي موقع HackerRank
#
# ثانياً : كل مسألة تتكون من ثلاثة اجزاء ...
#
# (جزء الشرح وأمثلة + جزء لكتابة الكود + جزء نتيجة تشغيل الكود)
#
# ثالثاً : لكل مسألة (واجب) يتم الآتي :-
#
# - يتم تصوير الكود اللي كتبته .. يحفظ كصورة
#
# - ثم يتم تصوير نتيجة تشغيل الكود .. يحفظ كصورة
#
#  Submit Code بعد عمل
#
# - يتم وضع الصورتين في ملف وورد وحفظه باسمك مثلاً ورقم المسألة
#
# - يتم ارسال حل الواجب كالتالي :
#
# *** إما ملف وورد بامتداد DOC أو DOCX
#
# *** أو ملف بي دي اف PDF
#
# ...
# ...
#
# تابع علي الرابط التالي لتسليم الواجب :
#
# https://www.rwaq.org/courses/data-scientist-from0/sections
#
# ...
# بالتوفيق للجميع
# ...

# %% [markdown]
# **{ التسجيل فى موقع هكر رانك  Hacker Rank }**

# %% [markdown]
# ![hackerRank registeration 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![hackerRank registeration 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Brackets Name.jpg](data:image/jpeg;base64,...)
# **أسماء الأقواس وأنواعها وما تدل عليه في بايثون :**
#
#     1- Brackets : [ ] أقواس مربعة ... List
#
#     2- parentheses : ( ) أقواس دائرية ... Tuple
#
#     3- Braces : { } أقواس معقوفة ... Set -or- Dictionary
# ...

# %% [markdown]
# ![أنواع البيانات في بايثون.jpg](data:image/jpeg;base64,...)
# **أنواع البيانات في بايثون Data Types in Python :**
#
#     1- Integer :  5 ... عدد صحيح
#     2- Float :  5.5  ... عدد عشري
#     3- String : ... بيانات نصية
#  توضع بين علامات التنصيص
#  "علم البيانات - رواق"
#
#     4- List : [1,2,3,4,5,6]
#     5- Tuple : (1,2,3,4,5,6)
#     6- Set : {1,2,3,4,5,6}
#     7- Dictionary : {a:1, b:2, c:3, d:4, e:5, f:6}
# ...

# %% [markdown]
# ![Data Type - Order - Mutable.jpg](data:image/jpeg;base64,...)
#
# **أنواع البيانات Data Types :**
#
# 1- هل هي مفهرسة ومرتبة :
#
# Ordered مرتبة ومفهرسة / UnOrdered غير مرتبة وغير مفهرسة
#
# 2- هل تقبل التغيير :
#
# Mutable قابل للتعديل / Immutable غير قابل للتعديل
#
# ...

# %% [markdown]
# **معلومات تهمك في هكر رانك :**
#
#
# 1- stdin = standard input :
#
#  مدخلات سيأخذها البرنامج من المستخدم
#
# 2- stdout = standard output :
#
# مخرجات يتم طباعتها والحصول عليها من البرنامج
#
# 3- Your Output (stdout) :
#
# المخرجات أو نتيجة تنفيذ البرنامج الذي كتبته
#
# 4- Expected Output :
#
# المخرجات المتوقع الحصول عليها من تنفيذ البرنامج - اللي هيا الواجب المطلوب
#
# ...
#
# **عند عمل تشغيل الكود Run Code يجب أن يكون :**
#
# ** نتيجة البرنامج الذي كتبته مطابقة للنتيجة المتوقعة من البرنامج
#
#  Your Output (stdout) = Expected Output
#
# ...
# ...
#
# **يجب قراءة صفحة المشكلة جيداً :**
#
# ( لأن بها شرح هام وأمثلة علي المطلوب تنفيذه )
#
# ...
# ...
#
# **عند انتهائك من كتابة الكود في هكر رانك :**
#
# 1- للتاكد من صحة الكود الخاص بك :
#
# تضغط زر Run Code للتأكد من صحة اجابتك وكتابتك للبرنامج.
#
#
# 2- اذا كانت اجابتك صحيحة :
#
# تقوم بضغط زر Submit Code لارسال اجابتك والحصول علي درجات تضاف لحسابك في هكر رانك.
#
# ...
# ...

# %% [markdown]
# ***************************************************************

# %% [markdown]
# ![حل الواجب - علم البيانات - رواق.jpg](data:image/jpeg;base64,...)
#
# **شرح فيديو لحل أول مسألة Problem1**
#
# مساق علم البيانات منصة رواق
#
# ...
#
# **Problem No1 : Say "Hello World!"**
#
# https://www.hackerrank.com/challenges/py-hello-world/problem
#
# ...
#
# **شرح فيديو لحل المسألة**
#
# https://www.youtube.com/watch?v=YXwdnbySsy4

# %% [markdown]
# ***************************************************************

# %% [markdown]
# ![شروحات هامة - مساق علم البيانات - منصة رواق.jpeg](data:image/jpeg;base64,...)
#
# ...
#
#
# **تحديث جديد بتاريخ 30-9-2021**
# -------------------------------------------------
#
#
# **ده شرح التعامل مع مساق علم البيانات + شرح لحل أول واجب**
#
#  **Problem1 Solving No1**
#
# ...
#
#
# **1- شرح التعامل مع مساق علم البيانات علي منصة رواق**
#
# https://youtu.be/qnmQJLSN0Pc
#
#
# ...
#
#
# **2- شرح لحل أول واجب - مساق علم البيانات علي منصة رواق**
#
# https://youtu.be/YXwdnbySsy4
#
# ...
#
#
#
# **للأهمية :**
#
# **ملحوظة : الشروحات بجودة عالية**
#
# **للمشاهدة : اختر جودة الفيديو لا تقل عن**
#
# **HD 720 - أو -  Full HD 1080p**
#
# ...
# ...
#
#
# **3- للأهمية : يرجي متابعة هذا الملف باستمرار :**
#
# DataScience_Rwaq_SamehDorgham_Notes
#
# https://bit.ly/SamehDorgham_Notes
#
# ...
# ...
# ...
#
# **نزول الواجب رقم 3 المطلوب حله علي هكر رانك**
# -------------------------------------------------------
#
# **problem solving 3**
# -------------------------------------------------------
#
# https://www.hackerrank.com/challenges/python-division/problem
#
# ...
#
# بالتوفيق للجميع

# %% [markdown]
# ***********************************************************

# %% [markdown]
# *********************************************************
#
#
# ![مساق علم البيانات - GitHub.jpg](data:image/jpeg;base64,...)
#
#
# **علم البيانات - رواق**
#
# https://www.rwaq.org/courses/data-scientist-from0
#
# ...
# ...
#
#
# **واتس الباشمهندس / مصطفي نبيه**
#
# **PHONE : +201015197566**
#
# ...
# ...
# ...
#
# *********************************************************
